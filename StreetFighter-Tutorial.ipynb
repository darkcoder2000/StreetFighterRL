# %% [markdown]
# # Street Fighter Tutorial
# This notebook accompanies the YouTube tutorial on <a href='https://www.youtube.com/c/NicholasRenotte'>Nicholas Renotte</a>

# %% [markdown]
# # Setup StreetFighter

# %%
# !pip install gym[all] gym-retro
# !pip install pygame
# !pip install opencv-python
# !pip install matplotlib
# !pip install torch==1.10.2+cu113 torchvision==0.11.3+cu113 torchaudio===0.10.2+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# !pip install stable-baselines3[extra] optuna

# %%
# Import retro to play Street Fighter using a ROM
import retro
# Import time to slow down game
import time

# %%
# See the different retro games
retro.data.list_games()

# %%
# python -m retro.import . # Run this from the roms folder, or where you have your game roms

# %% [markdown]
# # Setup Environment
# ## What we are going to do! FUNNN
# - Observation Preprocess - grayscale (DONE), frame delta, resize the frame so we have less pixels  (DONE)
# - Filter the action - parameter DONE
# - Reward function - set this to the score

# %%
# Import environment base class for a wrapper 
from gym import Env 
# Import the space shapes for the environment
from gym.spaces import MultiBinary, Box
# Import numpy to calculate frame delta 
import numpy as np
# Import opencv for grayscaling
import cv2
# Import matplotlib for plotting the image
from matplotlib import pyplot as plt

# %%
# Create custom environment 
class StreetFighter(Env): 
    def __init__(self):
        super().__init__()
        # Specify action space and observation space 
        self.observation_space = Box(low=0, high=255, shape=(84, 84, 1), dtype=np.uint8)
        self.action_space = MultiBinary(12)
        # Startup and instance of the game 
        self.game = retro.make(game='StreetFighterIISpecialChampionEdition-Genesis', use_restricted_actions=retro.Actions.FILTERED)
    
    def reset(self):
        # Return the first frame 
        obs = self.game.reset()
        obs = self.preprocess(obs) 
        self.previous_frame = obs 
        
        # Create a attribute to hold the score delta 
        self.score = 0 
        return obs
    
    def preprocess(self, observation): 
        # Grayscaling 
        gray = cv2.cvtColor(observation, cv2.COLOR_BGR2GRAY)
        # Resize 
        resize = cv2.resize(gray, (84,84), interpolation=cv2.INTER_CUBIC)
        # Add the channels value
        channels = np.reshape(resize, (84,84,1))
        return channels 
    
    def step(self, action): 
        # Take a step 
        obs, reward, done, info = self.game.step(action)
        obs = self.preprocess(obs) 
        
        # Frame delta 
        frame_delta = obs - self.previous_frame
        self.previous_frame = obs 
        
        # Reshape the reward function
        reward = info['score'] - self.score 
        self.score = info['score'] 
        
        return frame_delta, reward, done, info
    
    def render(self, *args, **kwargs):
        self.game.render()
        
    def close(self):
        self.game.close()

# %% [markdown]
# # Hyperparameter tune

# %%
# Importing the optimzation frame - HPO
import optuna
# PPO algo for RL
from stable_baselines3 import PPO
# Bring in the eval policy method for metric calculation
from stable_baselines3.common.evaluation import evaluate_policy
# Import the sb3 monitor for logging 
from stable_baselines3.common.monitor import Monitor
# Import the vec wrappers to vectorize and frame stack
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
# Import os to deal with filepaths
import os

# %%
LOG_DIR = './logs/'
OPT_DIR = './opt/'

# %%
# Function to return test hyperparameters - define the object function
def optimize_ppo(trial): 
    return {
        'n_steps':trial.suggest_int('n_steps', 2048, 8192),
        'gamma':trial.suggest_loguniform('gamma', 0.8, 0.9999),
        'learning_rate':trial.suggest_loguniform('learning_rate', 1e-5, 1e-4),
        'clip_range':trial.suggest_uniform('clip_range', 0.1, 0.4),
        'gae_lambda':trial.suggest_uniform('gae_lambda', 0.8, 0.99)
    }

# %%
SAVE_PATH = os.path.join(OPT_DIR, 'trial_{}_best_model'.format(1))

# %%
# Run a training loop and return mean reward 
def optimize_agent(trial):
    try:
        model_params = optimize_ppo(trial) 

        # Create environment 
        env = StreetFighter()
        env = Monitor(env, LOG_DIR)
        env = DummyVecEnv([lambda: env])
        env = VecFrameStack(env, 4, channels_order='last')

        # Create algo 
        model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=0, **model_params)
        #model.learn(total_timesteps=30000)
        model.learn(total_timesteps=50000)

        # Evaluate model 
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=5)
        env.close()

        SAVE_PATH = os.path.join(OPT_DIR, 'trial_{}_best_model'.format(trial.number))
        model.save(SAVE_PATH)

        return mean_reward

    except Exception as e:
        print(e)
        return -1000

# %%
# Creating the experiment 
study = optuna.create_study(direction='maximize')
study.optimize(optimize_agent, n_trials=50, n_jobs=1)
#study.optimize(optimize_agent, n_trials=100, n_jobs=1)
# Out:
# [I 2022-02-20 12:11:11,581] A new study created in memory with name: no-name-e8703b8c-eaea-49b4-8f25-af561edabea7
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4907`, after every 76 untruncated mini-batches, there will be a truncated mini-batch of size 43
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4907 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 12:17:26,992] Trial 0 finished with value: 2700.0 and parameters: {'n_steps': 4907, 'gamma': 0.8128099333446631, 'learning_rate': 2.5434615459478538e-05, 'clip_range': 0.29328195874236473, 'gae_lambda': 0.8650270744429742}. Best is trial 0 with value: 2700.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7495`, after every 117 untruncated mini-batches, there will be a truncated mini-batch of size 7
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7495 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 12:22:55,060] Trial 1 finished with value: 2000.0 and parameters: {'n_steps': 7495, 'gamma': 0.8421510608912435, 'learning_rate': 5.920472143790282e-05, 'clip_range': 0.28111880704291303, 'gae_lambda': 0.9011007801571661}. Best is trial 0 with value: 2700.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3238`, after every 50 untruncated mini-batches, there will be a truncated mini-batch of size 38
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3238 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 12:28:46,419] Trial 2 finished with value: 26800.0 and parameters: {'n_steps': 3238, 'gamma': 0.8399696761018833, 'learning_rate': 4.851277950807087e-05, 'clip_range': 0.3610132504470336, 'gae_lambda': 0.8321422625930855}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7891`, after every 123 untruncated mini-batches, there will be a truncated mini-batch of size 19
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7891 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 12:35:24,093] Trial 3 finished with value: 4700.0 and parameters: {'n_steps': 7891, 'gamma': 0.8335175185377717, 'learning_rate': 4.650314639041922e-05, 'clip_range': 0.2588243318672908, 'gae_lambda': 0.8585067064635751}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5995`, after every 93 untruncated mini-batches, there will be a truncated mini-batch of size 43
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5995 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 12:42:18,075] Trial 4 finished with value: 0.0 and parameters: {'n_steps': 5995, 'gamma': 0.9025464624426396, 'learning_rate': 5.3350086365866155e-05, 'clip_range': 0.3766443370950059, 'gae_lambda': 0.9034996310130203}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6722`, after every 105 untruncated mini-batches, there will be a truncated mini-batch of size 2
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6722 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 12:48:06,304] Trial 5 finished with value: 3100.0 and parameters: {'n_steps': 6722, 'gamma': 0.8263000788155138, 'learning_rate': 3.119477419621803e-05, 'clip_range': 0.10957218637934223, 'gae_lambda': 0.9300203980128194}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5931`, after every 92 untruncated mini-batches, there will be a truncated mini-batch of size 43
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5931 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 12:54:06,898] Trial 6 finished with value: 2000.0 and parameters: {'n_steps': 5931, 'gamma': 0.8860868707656169, 'learning_rate': 1.063627283728318e-05, 'clip_range': 0.14873286213047848, 'gae_lambda': 0.9253434899378589}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7204`, after every 112 untruncated mini-batches, there will be a truncated mini-batch of size 36
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7204 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 12:59:35,017] Trial 7 finished with value: 2000.0 and parameters: {'n_steps': 7204, 'gamma': 0.9449367411254003, 'learning_rate': 1.8114072307152548e-05, 'clip_range': 0.32658472385502973, 'gae_lambda': 0.9222221220484776}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6572`, after every 102 untruncated mini-batches, there will be a truncated mini-batch of size 44
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6572 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:05:00,982] Trial 8 finished with value: 6900.0 and parameters: {'n_steps': 6572, 'gamma': 0.9020535540865902, 'learning_rate': 1.0696196993929413e-05, 'clip_range': 0.3534804816277217, 'gae_lambda': 0.8419805979573748}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6169`, after every 96 untruncated mini-batches, there will be a truncated mini-batch of size 25
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6169 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:10:51,041] Trial 9 finished with value: 3100.0 and parameters: {'n_steps': 6169, 'gamma': 0.8825615462085272, 'learning_rate': 2.2034208658222427e-05, 'clip_range': 0.10995067420078584, 'gae_lambda': 0.8916602814979129}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2856`, after every 44 untruncated mini-batches, there will be a truncated mini-batch of size 40
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2856 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:16:17,647] Trial 10 finished with value: 2000.0 and parameters: {'n_steps': 2856, 'gamma': 0.9861668216581577, 'learning_rate': 9.148889188951498e-05, 'clip_range': 0.21973917569228626, 'gae_lambda': 0.8008456278260238}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3868`, after every 60 untruncated mini-batches, there will be a truncated mini-batch of size 28
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3868 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:21:51,973] Trial 11 finished with value: 2000.0 and parameters: {'n_steps': 3868, 'gamma': 0.9226074104056786, 'learning_rate': 1.0388934471049899e-05, 'clip_range': 0.398809248171567, 'gae_lambda': 0.8127944630636348}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2282`, after every 35 untruncated mini-batches, there will be a truncated mini-batch of size 42
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2282 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:27:24,156] Trial 12 finished with value: 2000.0 and parameters: {'n_steps': 2282, 'gamma': 0.8604729063993817, 'learning_rate': 1.5488027948501903e-05, 'clip_range': 0.3459810422872461, 'gae_lambda': 0.9771121477508606}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4731`, after every 73 untruncated mini-batches, there will be a truncated mini-batch of size 59
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4731 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:33:03,806] Trial 13 finished with value: 2200.0 and parameters: {'n_steps': 4731, 'gamma': 0.8022922900163445, 'learning_rate': 3.690324730986279e-05, 'clip_range': 0.3338420512981758, 'gae_lambda': 0.8378901394182973}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3999`, after every 62 untruncated mini-batches, there will be a truncated mini-batch of size 31
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3999 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:38:25,666] Trial 14 finished with value: 2500.0 and parameters: {'n_steps': 3999, 'gamma': 0.8654524893428189, 'learning_rate': 8.718452543892006e-05, 'clip_range': 0.21276809763295096, 'gae_lambda': 0.830580155466101}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3370`, after every 52 untruncated mini-batches, there will be a truncated mini-batch of size 42
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3370 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:43:51,832] Trial 15 finished with value: 4500.0 and parameters: {'n_steps': 3370, 'gamma': 0.9478824209682156, 'learning_rate': 7.010516623494567e-05, 'clip_range': 0.35735766463966145, 'gae_lambda': 0.861534704289054}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5333`, after every 83 untruncated mini-batches, there will be a truncated mini-batch of size 21
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5333 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:49:07,475] Trial 16 finished with value: 3000.0 and parameters: {'n_steps': 5333, 'gamma': 0.9197110339183294, 'learning_rate': 4.089209700840214e-05, 'clip_range': 0.3035711960162226, 'gae_lambda': 0.8317867569536325}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2089`, after every 32 untruncated mini-batches, there will be a truncated mini-batch of size 41
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2089 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 13:54:22,421] Trial 17 finished with value: 2000.0 and parameters: {'n_steps': 2089, 'gamma': 0.8563903693342179, 'learning_rate': 1.5247763015889634e-05, 'clip_range': 0.3998314600489118, 'gae_lambda': 0.8774970714284801}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4144`, after every 64 untruncated mini-batches, there will be a truncated mini-batch of size 48
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4144 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:00:19,012] Trial 18 finished with value: 2000.0 and parameters: {'n_steps': 4144, 'gamma': 0.9961005374566775, 'learning_rate': 2.7938149446399526e-05, 'clip_range': 0.23069428011407464, 'gae_lambda': 0.844612853731488}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6611`, after every 103 untruncated mini-batches, there will be a truncated mini-batch of size 19
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6611 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:05:31,617] Trial 19 finished with value: 2000.0 and parameters: {'n_steps': 6611, 'gamma': 0.9007074703169876, 'learning_rate': 6.898380680197572e-05, 'clip_range': 0.17787159470289005, 'gae_lambda': 0.8146771488131196}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5559`, after every 86 untruncated mini-batches, there will be a truncated mini-batch of size 55
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5559 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:10:52,894] Trial 20 finished with value: 21000.0 and parameters: {'n_steps': 5559, 'gamma': 0.9635825681636777, 'learning_rate': 1.3751703438977667e-05, 'clip_range': 0.3110358120140902, 'gae_lambda': 0.8804474109118945}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5538`, after every 86 untruncated mini-batches, there will be a truncated mini-batch of size 34
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5538 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:17:10,121] Trial 21 finished with value: 17400.0 and parameters: {'n_steps': 5538, 'gamma': 0.951325585988622, 'learning_rate': 1.3126866576438128e-05, 'clip_range': 0.31111997641817446, 'gae_lambda': 0.8812264198379876}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5393`, after every 84 untruncated mini-batches, there will be a truncated mini-batch of size 17
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5393 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:22:48,954] Trial 22 finished with value: 4100.0 and parameters: {'n_steps': 5393, 'gamma': 0.9682755972706505, 'learning_rate': 1.291324551731101e-05, 'clip_range': 0.3137856074607187, 'gae_lambda': 0.8849547624381692}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4587`, after every 71 untruncated mini-batches, there will be a truncated mini-batch of size 43
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4587 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:28:02,346] Trial 23 finished with value: 2800.0 and parameters: {'n_steps': 4587, 'gamma': 0.9577616362384731, 'learning_rate': 2.0314787733095498e-05, 'clip_range': 0.2628939354402514, 'gae_lambda': 0.9595933549370939}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5657`, after every 88 untruncated mini-batches, there will be a truncated mini-batch of size 25
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5657 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:33:23,429] Trial 24 finished with value: 2100.0 and parameters: {'n_steps': 5657, 'gamma': 0.9289175024400674, 'learning_rate': 1.3475355417488835e-05, 'clip_range': 0.37169811456734875, 'gae_lambda': 0.8737939098627564}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3107`, after every 48 untruncated mini-batches, there will be a truncated mini-batch of size 35
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3107 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:40:32,155] Trial 25 finished with value: 1300.0 and parameters: {'n_steps': 3107, 'gamma': 0.9390418099890042, 'learning_rate': 3.658381231451181e-05, 'clip_range': 0.2803794049231451, 'gae_lambda': 0.9462442469710213}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5063`, after every 79 untruncated mini-batches, there will be a truncated mini-batch of size 7
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5063 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:46:45,491] Trial 26 finished with value: 2100.0 and parameters: {'n_steps': 5063, 'gamma': 0.9711985244583052, 'learning_rate': 1.8046442150298765e-05, 'clip_range': 0.31610097597994313, 'gae_lambda': 0.9072305198823174}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4338`, after every 67 untruncated mini-batches, there will be a truncated mini-batch of size 50
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4338 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:53:15,608] Trial 27 finished with value: 2000.0 and parameters: {'n_steps': 4338, 'gamma': 0.9781465285861591, 'learning_rate': 2.3280209737230588e-05, 'clip_range': 0.37680729931328055, 'gae_lambda': 0.8542620770955334}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3626`, after every 56 untruncated mini-batches, there will be a truncated mini-batch of size 42
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3626 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 14:59:27,583] Trial 28 finished with value: 2100.0 and parameters: {'n_steps': 3626, 'gamma': 0.9984700937684273, 'learning_rate': 1.2817694909327348e-05, 'clip_range': 0.3352778101467561, 'gae_lambda': 0.877122959409778}. Best is trial 2 with value: 26800.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5024`, after every 78 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5024 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:06:21,910] Trial 29 finished with value: 35300.0 and parameters: {'n_steps': 5024, 'gamma': 0.8189709083805853, 'learning_rate': 2.650192325308733e-05, 'clip_range': 0.2947393915843855, 'gae_lambda': 0.9161058440080572}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2573`, after every 40 untruncated mini-batches, there will be a truncated mini-batch of size 13
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2573 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:12:29,411] Trial 30 finished with value: 2000.0 and parameters: {'n_steps': 2573, 'gamma': 0.81751252214279, 'learning_rate': 2.7020329911868128e-05, 'clip_range': 0.290125993908761, 'gae_lambda': 0.9375345443227298}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5058`, after every 79 untruncated mini-batches, there will be a truncated mini-batch of size 2
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5058 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:18:47,273] Trial 31 finished with value: 4800.0 and parameters: {'n_steps': 5058, 'gamma': 0.8050332113772543, 'learning_rate': 1.5660448627269095e-05, 'clip_range': 0.2980277435967677, 'gae_lambda': 0.9083809987295547}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5619`, after every 87 untruncated mini-batches, there will be a truncated mini-batch of size 51
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5619 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:24:41,643] Trial 32 finished with value: 1300.0 and parameters: {'n_steps': 5619, 'gamma': 0.8417507862130222, 'learning_rate': 5.1808354586663006e-05, 'clip_range': 0.27631820899465204, 'gae_lambda': 0.9143350845164299}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4586`, after every 71 untruncated mini-batches, there will be a truncated mini-batch of size 42
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4586 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:30:27,005] Trial 33 finished with value: 4600.0 and parameters: {'n_steps': 4586, 'gamma': 0.8206299035172753, 'learning_rate': 4.262158220010936e-05, 'clip_range': 0.24051364722854784, 'gae_lambda': 0.8640022809776701}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6223`, after every 97 untruncated mini-batches, there will be a truncated mini-batch of size 15
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6223 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:37:17,348] Trial 34 finished with value: 500.0 and parameters: {'n_steps': 6223, 'gamma': 0.8321860652346572, 'learning_rate': 3.090975670238945e-05, 'clip_range': 0.26029506515762274, 'gae_lambda': 0.8940296987616319}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7062`, after every 110 untruncated mini-batches, there will be a truncated mini-batch of size 22
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7062 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:43:56,774] Trial 35 finished with value: 2000.0 and parameters: {'n_steps': 7062, 'gamma': 0.8404529498795568, 'learning_rate': 6.097279130480938e-05, 'clip_range': 0.3150754141437423, 'gae_lambda': 0.9488555120610287}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7786`, after every 121 untruncated mini-batches, there will be a truncated mini-batch of size 42
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7786 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:50:58,992] Trial 36 finished with value: 0.0 and parameters: {'n_steps': 7786, 'gamma': 0.8514908430989112, 'learning_rate': 1.864701770882538e-05, 'clip_range': 0.3717297061505918, 'gae_lambda': 0.8953861426186579}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5816`, after every 90 untruncated mini-batches, there will be a truncated mini-batch of size 56
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5816 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 15:56:22,305] Trial 37 finished with value: 2000.0 and parameters: {'n_steps': 5816, 'gamma': 0.9576600179780396, 'learning_rate': 1.1651104905662342e-05, 'clip_range': 0.2741535403697738, 'gae_lambda': 0.8842405966014186}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6373`, after every 99 untruncated mini-batches, there will be a truncated mini-batch of size 37
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6373 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:02:20,880] Trial 38 finished with value: 2200.0 and parameters: {'n_steps': 6373, 'gamma': 0.8731397570022567, 'learning_rate': 2.4708926079174014e-05, 'clip_range': 0.34496927600149035, 'gae_lambda': 0.8522465617138963}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6977`, after every 109 untruncated mini-batches, there will be a truncated mini-batch of size 1
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6977 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:02:42,608] Trial 39 finished with value: -1000.0 and parameters: {'n_steps': 6977, 'gamma': 0.8272811689769621, 'learning_rate': 3.415049193354554e-05, 'clip_range': 0.2984808581899395, 'gae_lambda': 0.9203692159198322}. Best is trial 29 with value: 35300.0.
# Expected parameter logits (Tensor of shape (64, 12)) of distribution Bernoulli(logits: torch.Size([64, 12])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5380`, after every 84 untruncated mini-batches, there will be a truncated mini-batch of size 4
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5380 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:09:06,761] Trial 40 finished with value: 2000.0 and parameters: {'n_steps': 5380, 'gamma': 0.9167225400922788, 'learning_rate': 4.93084417949993e-05, 'clip_range': 0.3214016980588021, 'gae_lambda': 0.8712019866883192}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7308`, after every 114 untruncated mini-batches, there will be a truncated mini-batch of size 12
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7308 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:14:17,286] Trial 41 finished with value: 2300.0 and parameters: {'n_steps': 7308, 'gamma': 0.9107392037741536, 'learning_rate': 1.043060830123758e-05, 'clip_range': 0.3559459070300301, 'gae_lambda': 0.8225105211921662}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6648`, after every 103 untruncated mini-batches, there will be a truncated mini-batch of size 56
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6648 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:19:53,299] Trial 42 finished with value: 1600.0 and parameters: {'n_steps': 6648, 'gamma': 0.8946712904521799, 'learning_rate': 1.1651948123715393e-05, 'clip_range': 0.3547231343082227, 'gae_lambda': 0.8493823823429331}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7568`, after every 118 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7568 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:25:59,694] Trial 43 finished with value: 2900.0 and parameters: {'n_steps': 7568, 'gamma': 0.9317542989406323, 'learning_rate': 1.3945790003833187e-05, 'clip_range': 0.34166586850446223, 'gae_lambda': 0.8436049931675526}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6401`, after every 100 untruncated mini-batches, there will be a truncated mini-batch of size 1
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6401 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:26:19,429] Trial 44 finished with value: -1000.0 and parameters: {'n_steps': 6401, 'gamma': 0.8808170115266898, 'learning_rate': 1.1504790230808727e-05, 'clip_range': 0.3777337808787323, 'gae_lambda': 0.8231958071375662}. Best is trial 29 with value: 35300.0.
# Expected parameter logits (Tensor of shape (64, 12)) of distribution Bernoulli(logits: torch.Size([64, 12])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6129`, after every 95 untruncated mini-batches, there will be a truncated mini-batch of size 49
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6129 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:32:00,094] Trial 45 finished with value: 2000.0 and parameters: {'n_steps': 6129, 'gamma': 0.9553057708166062, 'learning_rate': 1.5071874330716572e-05, 'clip_range': 0.326947936673088, 'gae_lambda': 0.9008657589294249}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5923`, after every 92 untruncated mini-batches, there will be a truncated mini-batch of size 35
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5923 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:37:31,082] Trial 46 finished with value: 500.0 and parameters: {'n_steps': 5923, 'gamma': 0.8090218293939454, 'learning_rate': 1.8172980184505882e-05, 'clip_range': 0.3890063519160743, 'gae_lambda': 0.885893420469851}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 8088`, after every 126 untruncated mini-batches, there will be a truncated mini-batch of size 24
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=8088 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:43:37,286] Trial 47 finished with value: 3100.0 and parameters: {'n_steps': 8088, 'gamma': 0.9823878853274536, 'learning_rate': 1.6622180427802498e-05, 'clip_range': 0.304556759146832, 'gae_lambda': 0.8010907733494445}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3445`, after every 53 untruncated mini-batches, there will be a truncated mini-batch of size 53
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3445 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:49:27,589] Trial 48 finished with value: 2000.0 and parameters: {'n_steps': 3445, 'gamma': 0.9075890608072061, 'learning_rate': 1.0036672651320233e-05, 'clip_range': 0.3631312201280952, 'gae_lambda': 0.8694243656169742}. Best is trial 29 with value: 35300.0.
# C:\Users\SESA59632\Anaconda3\envs\RL_StreetFighter\lib\site-packages\stable_baselines3\ppo\ppo.py:138: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4901`, after every 76 untruncated mini-batches, there will be a truncated mini-batch of size 37
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4901 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# [I 2022-02-20 16:54:57,853] Trial 49 finished with value: 2500.0 and parameters: {'n_steps': 4901, 'gamma': 0.8683426255880484, 'learning_rate': 2.188982590499276e-05, 'clip_range': 0.28702587357851556, 'gae_lambda': 0.9300293104178996}. Best is trial 29 with value: 35300.0.

# %%
study.best_params
# Out:
# {'n_steps': 5024,
#  'gamma': 0.8189709083805853,
#  'learning_rate': 2.650192325308733e-05,
#  'clip_range': 0.2947393915843855,
#  'gae_lambda': 0.9161058440080572}

# %%
study.best_trial
# Out:
# FrozenTrial(number=29, values=[35300.0], datetime_start=datetime.datetime(2022, 2, 20, 14, 59, 27, 584115), datetime_complete=datetime.datetime(2022, 2, 20, 15, 6, 21, 910247), params={'n_steps': 5024, 'gamma': 0.8189709083805853, 'learning_rate': 2.650192325308733e-05, 'clip_range': 0.2947393915843855, 'gae_lambda': 0.9161058440080572}, distributions={'n_steps': IntUniformDistribution(high=8192, low=2048, step=1), 'gamma': LogUniformDistribution(high=0.9999, low=0.8), 'learning_rate': LogUniformDistribution(high=0.0001, low=1e-05), 'clip_range': UniformDistribution(high=0.4, low=0.1), 'gae_lambda': UniformDistribution(high=0.99, low=0.8)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=29, state=TrialState.COMPLETE, value=None)

# %%
model = PPO.load(os.path.join(OPT_DIR, 'trial_29_best_model.zip'))

# %% [markdown]
# # Setup Callback

# %%
# Import base callback 
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # Train Model

# %%
# Create environment 
env = StreetFighter()
env = Monitor(env, LOG_DIR)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last')

# %%
model_params = study.best_params
model_params['n_steps'] = 4992  # set n_steps to 7488 or a factor of 64
model_params['learning_rate'] = 5e-7
model_params
# Out:
# {'n_steps': 4992,
#  'gamma': 0.8189709083805853,
#  'learning_rate': 5e-07,
#  'clip_range': 0.2947393915843855,
#  'gae_lambda': 0.9161058440080572}

# %%
#model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, **model_params)
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# Reload previous weights from HPO
model.load(os.path.join('train', 'best_model_5000000.zip'))

# %%
# Kick off training 
model.learn(total_timesteps=5000000, callback=callback)
# model.learn(total_timestep=5000000)
# Out:
# Logging to ./logs/PPO_52
# -----------------------------
# | time/              |      |
# |    fps             | 276  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 216        |
# |    iterations           | 2          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.60310304 |
# |    clip_fraction        | 0.629      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.73      |
# |    explained_variance   | 2.46e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.34e+04   |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.106      |
# |    value_loss           | 5.15e+06   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 201       |
# |    iterations           | 3         |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 17.276077 |
# |    clip_fraction        | 0.972     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.34     |
# |    explained_variance   | 0.13      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.37e+03  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | 0.23      |
# |    value_loss           | 2.13e+05  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 196       |
# |    iterations           | 4         |
# |    time_elapsed         | 41        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 36.285545 |
# |    clip_fraction        | 0.973     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.27     |
# |    explained_variance   | -2.16     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.02e+03  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | 0.282     |
# |    value_loss           | 3.68e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 8.78e+03 |
# |    ep_rew_mean          | 6.45e+04 |
# | time/                   |          |
# |    fps                  | 193      |
# |    iterations           | 5        |
# |    time_elapsed         | 52       |
# |    total_timesteps      | 10240    |
# | train/                  |          |
# |    approx_kl            | 51.65356 |
# |    clip_fraction        | 0.954    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.731   |
# |    explained_variance   | -0.229   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 54.7     |
# |    n_updates            | 40       |
# |    policy_gradient_loss | 0.319    |
# |    value_loss           | 337      |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.78e+03   |
# |    ep_rew_mean          | 6.45e+04   |
# | time/                   |            |
# |    fps                  | 190        |
# |    iterations           | 6          |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.25376403 |
# |    clip_fraction        | 0.431      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.433     |
# |    explained_variance   | -0.203     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 86         |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.0531     |
# |    value_loss           | 144        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.78e+03   |
# |    ep_rew_mean          | 6.45e+04   |
# | time/                   |            |
# |    fps                  | 191        |
# |    iterations           | 7          |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.07333359 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.498     |
# |    explained_variance   | 0.0229     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.83e+03   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.00248    |
# |    value_loss           | 3.87e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.78e+03  |
# |    ep_rew_mean          | 6.45e+04  |
# | time/                   |           |
# |    fps                  | 188       |
# |    iterations           | 8         |
# |    time_elapsed         | 87        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 1.4429922 |
# |    clip_fraction        | 0.432     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.49     |
# |    explained_variance   | 0.44      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 11.6      |
# |    n_updates            | 70        |
# |    policy_gradient_loss | 0.0363    |
# |    value_loss           | 52.4      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.64e+03   |
# |    ep_rew_mean          | 3.32e+04   |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 9          |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.10289487 |
# |    clip_fraction        | 0.0743     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.205     |
# |    explained_variance   | 0.102      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.24e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.0124     |
# |    value_loss           | 3.33e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | 3.32e+04     |
# | time/                   |              |
# |    fps                  | 187          |
# |    iterations           | 10           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0019624343 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.084       |
# |    explained_variance   | 0.414        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000555     |
# |    value_loss           | 143          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.64e+03   |
# |    ep_rew_mean          | 3.32e+04   |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 11         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.08629636 |
# |    clip_fraction        | 0.0126     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00885   |
# |    explained_variance   | 0.0366     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 523        |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00166   |
# |    value_loss           | 2.76e+03   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | 3.32e+04      |
# | time/                   |               |
# |    fps                  | 188           |
# |    iterations           | 12            |
# |    time_elapsed         | 130           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.1699929e-06 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00275      |
# |    explained_variance   | 0.303         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 258           |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000114     |
# |    value_loss           | 2.29e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.34e+03     |
# |    ep_rew_mean          | 2.28e+04     |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 13           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 5.575553e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00289     |
# |    explained_variance   | -0.229       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.5         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 2.47e-05     |
# |    value_loss           | 234          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.34e+03    |
# |    ep_rew_mean          | 2.28e+04    |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 14          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016184952 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0962     |
# |    explained_variance   | 0.283       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 39.9        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.34e+03  |
# |    ep_rew_mean          | 2.28e+04  |
# | time/                   |           |
# |    fps                  | 189       |
# |    iterations           | 15        |
# |    time_elapsed         | 162       |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.3191443 |
# |    clip_fraction        | 0.0338    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0264   |
# |    explained_variance   | 0.141     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 163       |
# |    n_updates            | 140       |
# |    policy_gradient_loss | 0.0102    |
# |    value_loss           | 1.63e+03  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.18e+03     |
# |    ep_rew_mean          | 1.76e+04     |
# | time/                   |              |
# |    fps                  | 190          |
# |    iterations           | 16           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 9.787418e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000224    |
# |    explained_variance   | 0.649        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 281          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 5.58e-05     |
# |    value_loss           | 1.18e+03     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 8.18e+03       |
# |    ep_rew_mean          | 1.76e+04       |
# | time/                   |                |
# |    fps                  | 190            |
# |    iterations           | 17             |
# |    time_elapsed         | 182            |
# |    total_timesteps      | 34816          |
# | train/                  |                |
# |    approx_kl            | 1.15204294e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.000883      |
# |    explained_variance   | -0.225         |
# |    learning_rate        | 0.0003         |
# |    loss                 | 27.9           |
# |    n_updates            | 160            |
# |    policy_gradient_loss | 9.17e-06       |
# |    value_loss           | 217            |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.18e+03      |
# |    ep_rew_mean          | 1.76e+04      |
# | time/                   |               |
# |    fps                  | 191           |
# |    iterations           | 18            |
# |    time_elapsed         | 192           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 1.1862806e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00043      |
# |    explained_variance   | 0.425         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 128           |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -7.56e-06     |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.18e+03  |
# |    ep_rew_mean          | 1.76e+04  |
# | time/                   |           |
# |    fps                  | 191       |
# |    iterations           | 19        |
# |    time_elapsed         | 203       |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0379488 |
# |    clip_fraction        | 0.0594    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.129    |
# |    explained_variance   | -0.624    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 13.1      |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -0.0122   |
# |    value_loss           | 31.4      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.03e+03   |
# |    ep_rew_mean          | 1.45e+04   |
# | time/                   |            |
# |    fps                  | 191        |
# |    iterations           | 20         |
# |    time_elapsed         | 213        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.16537496 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.176     |
# |    explained_variance   | 0.379      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 54.8       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0249     |
# |    value_loss           | 831        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.03e+03  |
# |    ep_rew_mean          | 1.45e+04  |
# | time/                   |           |
# |    fps                  | 191       |
# |    iterations           | 21        |
# |    time_elapsed         | 224       |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.7122341 |
# |    clip_fraction        | 0.137     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.105    |
# |    explained_variance   | -0.0963   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.74      |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.0294    |
# |    value_loss           | 30.2      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.03e+03     |
# |    ep_rew_mean          | 1.45e+04     |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 22           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 9.994224e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00142     |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.4         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -6.19e-06    |
# |    value_loss           | 698          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.03e+03      |
# |    ep_rew_mean          | 1.45e+04      |
# | time/                   |               |
# |    fps                  | 192           |
# |    iterations           | 23            |
# |    time_elapsed         | 244           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00016093283 |
# |    clip_fraction        | 0.000488      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00901      |
# |    explained_variance   | -0.477        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.47          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -8.12e-05     |
# |    value_loss           | 22.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.94e+03     |
# |    ep_rew_mean          | 1.24e+04     |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 24           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0031283477 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00377     |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.3         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 4.04e-05     |
# |    value_loss           | 378          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.94e+03    |
# |    ep_rew_mean          | 1.24e+04    |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 25          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003194711 |
# |    clip_fraction        | 0.0101      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0216     |
# |    explained_variance   | -0.0207     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.41        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000116   |
# |    value_loss           | 15.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.94e+03     |
# |    ep_rew_mean          | 1.24e+04     |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 26           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0033819862 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0111      |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 546          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.000291     |
# |    value_loss           | 381          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.94e+03     |
# |    ep_rew_mean          | 1.24e+04     |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 27           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0021213489 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00433     |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -3.8e-05     |
# |    value_loss           | 515          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.91e+03    |
# |    ep_rew_mean          | 1.09e+04    |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 28          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.023087645 |
# |    clip_fraction        | 0.00942     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00719    |
# |    explained_variance   | -0.277      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000564   |
# |    value_loss           | 160         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.91e+03   |
# |    ep_rew_mean          | 1.09e+04   |
# | time/                   |            |
# |    fps                  | 193        |
# |    iterations           | 29         |
# |    time_elapsed         | 307        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.28668177 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0978    |
# |    explained_variance   | 0.577      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.5       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.01      |
# |    value_loss           | 298        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.91e+03   |
# |    ep_rew_mean          | 1.09e+04   |
# | time/                   |            |
# |    fps                  | 193        |
# |    iterations           | 30         |
# |    time_elapsed         | 317        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.11226569 |
# |    clip_fraction        | 0.0339     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0152    |
# |    explained_variance   | -0.201     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.73       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0279     |
# |    value_loss           | 10.7       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.88e+03     |
# |    ep_rew_mean          | 9.81e+03     |
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 31           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 8.345293e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.37e-05    |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.4         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -8.07e-06    |
# |    value_loss           | 298          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.88e+03      |
# |    ep_rew_mean          | 9.81e+03      |
# | time/                   |               |
# |    fps                  | 193           |
# |    iterations           | 32            |
# |    time_elapsed         | 338           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 2.7504615e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0015       |
# |    explained_variance   | -0.943        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.28          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | 1.98e-05      |
# |    value_loss           | 14.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.88e+03      |
# |    ep_rew_mean          | 9.81e+03      |
# | time/                   |               |
# |    fps                  | 194           |
# |    iterations           | 33            |
# |    time_elapsed         | 348           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 3.1659958e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.23e-05     |
# |    explained_variance   | 0.738         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 65.9          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | 7.64e-06      |
# |    value_loss           | 172           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.88e+03      |
# |    ep_rew_mean          | 9.81e+03      |
# | time/                   |               |
# |    fps                  | 194           |
# |    iterations           | 34            |
# |    time_elapsed         | 358           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 1.5676554e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00152      |
# |    explained_variance   | -0.139        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.765         |
# |    n_updates            | 330           |
# |    policy_gradient_loss | 2.31e-05      |
# |    value_loss           | 3.75          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.86e+03      |
# |    ep_rew_mean          | 8.94e+03      |
# | time/                   |               |
# |    fps                  | 194           |
# |    iterations           | 35            |
# |    time_elapsed         | 369           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 2.7917178e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.23e-05     |
# |    explained_variance   | 0.771         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 18.8          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 6.57e-06      |
# |    value_loss           | 150           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.86e+03     |
# |    ep_rew_mean          | 8.94e+03     |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 36           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 8.915925e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00251     |
# |    explained_variance   | -0.863       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 1.76e-05     |
# |    value_loss           | 8.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.86e+03     |
# |    ep_rew_mean          | 8.94e+03     |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 37           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0027474375 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000357    |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.19         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 1.64e-05     |
# |    value_loss           | 126          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.86e+03      |
# |    ep_rew_mean          | 8.94e+03      |
# | time/                   |               |
# |    fps                  | 194           |
# |    iterations           | 38            |
# |    time_elapsed         | 400           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 2.6738442e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00196      |
# |    explained_variance   | -0.495        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.549         |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 1.65e-05      |
# |    value_loss           | 2.18          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.85e+03      |
# |    ep_rew_mean          | 8.25e+03      |
# | time/                   |               |
# |    fps                  | 194           |
# |    iterations           | 39            |
# |    time_elapsed         | 410           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 2.9261976e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000187     |
# |    explained_variance   | 0.834         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 19.5          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 1.09e-05      |
# |    value_loss           | 116           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.85e+03      |
# |    ep_rew_mean          | 8.25e+03      |
# | time/                   |               |
# |    fps                  | 194           |
# |    iterations           | 40            |
# |    time_elapsed         | 420           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 2.3084414e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0031       |
# |    explained_variance   | -0.215        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.914         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000157     |
# |    value_loss           | 9.5           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.85e+03    |
# |    ep_rew_mean          | 8.25e+03    |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 41          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014938627 |
# |    clip_fraction        | 0.0188      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0448     |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.000545   |
# |    value_loss           | 71.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.85e+03    |
# |    ep_rew_mean          | 8.25e+03    |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 42          |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019130101 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0792     |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00289     |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.84e+03    |
# |    ep_rew_mean          | 7.68e+03    |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 43          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.037327614 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0409     |
# |    explained_variance   | -0.0273     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.9         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00729     |
# |    value_loss           | 26.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.84e+03    |
# |    ep_rew_mean          | 7.68e+03    |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 44          |
# |    time_elapsed         | 462         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.023743458 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0823     |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00323     |
# |    value_loss           | 97.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.84e+03   |
# |    ep_rew_mean          | 7.68e+03   |
# | time/                   |            |
# |    fps                  | 194        |
# |    iterations           | 45         |
# |    time_elapsed         | 473        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.08203359 |
# |    clip_fraction        | 0.0678     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0974    |
# |    explained_variance   | -1.27      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.189      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00323   |
# |    value_loss           | 1.09       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.83e+03   |
# |    ep_rew_mean          | 7.21e+03   |
# | time/                   |            |
# |    fps                  | 194        |
# |    iterations           | 46         |
# |    time_elapsed         | 483        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.07519293 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.241     |
# |    explained_variance   | 0.851      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 67.9       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.0197     |
# |    value_loss           | 86.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.83e+03   |
# |    ep_rew_mean          | 7.21e+03   |
# | time/                   |            |
# |    fps                  | 194        |
# |    iterations           | 47         |
# |    time_elapsed         | 493        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.06479296 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.291     |
# |    explained_variance   | -1.1       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.819      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 1.26       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.83e+03    |
# |    ep_rew_mean          | 7.21e+03    |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 48          |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.091554254 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.235      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0201      |
# |    value_loss           | 88.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.83e+03   |
# |    ep_rew_mean          | 7.21e+03   |
# | time/                   |            |
# |    fps                  | 194        |
# |    iterations           | 49         |
# |    time_elapsed         | 514        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.04367423 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.275     |
# |    explained_variance   | -1.07      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0949     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0162    |
# |    value_loss           | 0.48       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.82e+03   |
# |    ep_rew_mean          | 6.81e+03   |
# | time/                   |            |
# |    fps                  | 194        |
# |    iterations           | 50         |
# |    time_elapsed         | 525        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.09029621 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.283     |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.17       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.0188     |
# |    value_loss           | 77.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.82e+03    |
# |    ep_rew_mean          | 6.81e+03    |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 51          |
# |    time_elapsed         | 536         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.044536784 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.205      |
# |    explained_variance   | -0.676      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0797      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00698    |
# |    value_loss           | 0.825       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.82e+03   |
# |    ep_rew_mean          | 6.81e+03   |
# | time/                   |            |
# |    fps                  | 194        |
# |    iterations           | 52         |
# |    time_elapsed         | 546        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.11675007 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.194     |
# |    explained_variance   | 0.859      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.7        |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0145     |
# |    value_loss           | 90.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.82e+03    |
# |    ep_rew_mean          | 6.81e+03    |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 53          |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.031598277 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 0.756       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.81e+03    |
# |    ep_rew_mean          | 6.46e+03    |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 54          |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.037217475 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.208      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.14        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.00541     |
# |    value_loss           | 62.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.81e+03   |
# |    ep_rew_mean          | 6.46e+03   |
# | time/                   |            |
# |    fps                  | 194        |
# |    iterations           | 55         |
# |    time_elapsed         | 578        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.02340915 |
# |    clip_fraction        | 0.0917     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.161     |
# |    explained_variance   | -0.0796    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.72       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | 0.00184    |
# |    value_loss           | 4.56       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.81e+03  |
# |    ep_rew_mean          | 6.46e+03  |
# | time/                   |           |
# |    fps                  | 194       |
# |    iterations           | 56        |
# |    time_elapsed         | 589       |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# ...
# |    total_timesteps      | 1966080    |
# | train/                  |            |
# |    approx_kl            | 0.08807276 |
# |    clip_fraction        | 0.0107     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00612   |
# |    explained_variance   | 0.105      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.65e+03   |
# |    n_updates            | 9590       |
# |    policy_gradient_loss | 0.00551    |
# |    value_loss           | 2.76e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.28e+03   |
# |    ep_rew_mean          | 891        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 961        |
# |    time_elapsed         | 9855       |
# |    total_timesteps      | 1968128    |
# | train/                  |            |
# |    approx_kl            | 0.16268653 |
# |    clip_fraction        | 0.00742    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0026    |
# |    explained_variance   | -1.12      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.65       |
# |    n_updates            | 9600       |
# |    policy_gradient_loss | 0.00117    |
# |    value_loss           | 55.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28e+03    |
# |    ep_rew_mean          | 891         |
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 962         |
# |    time_elapsed         | 9865        |
# |    total_timesteps      | 1970176     |
# | train/                  |             |
# |    approx_kl            | 0.020485686 |
# |    clip_fraction        | 0.0084      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0175     |
# |    explained_variance   | -0.158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.5         |
# |    n_updates            | 9610        |
# |    policy_gradient_loss | 0.00213     |
# |    value_loss           | 15.9        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.28e+03  |
# |    ep_rew_mean          | 891       |
# | time/                   |           |
# |    fps                  | 199       |
# |    iterations           | 963       |
# |    time_elapsed         | 9875      |
# |    total_timesteps      | 1972224   |
# | train/                  |           |
# |    approx_kl            | 0.8357674 |
# |    clip_fraction        | 0.0329    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00793  |
# |    explained_variance   | 0.593     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.9       |
# |    n_updates            | 9620      |
# |    policy_gradient_loss | 0.0193    |
# |    value_loss           | 722       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.27e+03   |
# |    ep_rew_mean          | 901        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 964        |
# |    time_elapsed         | 9885       |
# |    total_timesteps      | 1974272    |
# | train/                  |            |
# |    approx_kl            | 0.08368118 |
# |    clip_fraction        | 0.00801    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00344   |
# |    explained_variance   | 0.209      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 583        |
# |    n_updates            | 9630       |
# |    policy_gradient_loss | -0.00337   |
# |    value_loss           | 1.13e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.27e+03  |
# |    ep_rew_mean          | 901       |
# | time/                   |           |
# |    fps                  | 199       |
# |    iterations           | 965       |
# |    time_elapsed         | 9895      |
# |    total_timesteps      | 1976320   |
# | train/                  |           |
# |    approx_kl            | 1.3026497 |
# |    clip_fraction        | 0.0234    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0356   |
# |    explained_variance   | 0.695     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 863       |
# |    n_updates            | 9640      |
# |    policy_gradient_loss | 0.00989   |
# |    value_loss           | 795       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.27e+03   |
# |    ep_rew_mean          | 911        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 966        |
# |    time_elapsed         | 9905       |
# |    total_timesteps      | 1978368    |
# | train/                  |            |
# |    approx_kl            | 0.39580327 |
# |    clip_fraction        | 0.0149     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00643   |
# |    explained_variance   | 0.58       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.8       |
# |    n_updates            | 9650       |
# |    policy_gradient_loss | 0.0206     |
# |    value_loss           | 947        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.27e+03  |
# |    ep_rew_mean          | 911       |
# | time/                   |           |
# |    fps                  | 199       |
# |    iterations           | 967       |
# |    time_elapsed         | 9916      |
# |    total_timesteps      | 1980416   |
# | train/                  |           |
# |    approx_kl            | 1.1819533 |
# |    clip_fraction        | 0.0353    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0862   |
# |    explained_variance   | 0.0956    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 86        |
# |    n_updates            | 9660      |
# |    policy_gradient_loss | 0.0168    |
# |    value_loss           | 789       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.27e+03   |
# |    ep_rew_mean          | 911        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 968        |
# |    time_elapsed         | 9926       |
# |    total_timesteps      | 1982464    |
# | train/                  |            |
# |    approx_kl            | 0.42910644 |
# |    clip_fraction        | 0.0246     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00661   |
# |    explained_variance   | 0.304      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.75       |
# |    n_updates            | 9670       |
# |    policy_gradient_loss | -0.00375   |
# |    value_loss           | 15.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.27e+03   |
# |    ep_rew_mean          | 921        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 969        |
# |    time_elapsed         | 9937       |
# |    total_timesteps      | 1984512    |
# | train/                  |            |
# |    approx_kl            | 0.14665093 |
# |    clip_fraction        | 0.00674    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0031    |
# |    explained_variance   | 0.713      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.2       |
# |    n_updates            | 9680       |
# |    policy_gradient_loss | 0.00523    |
# |    value_loss           | 250        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.27e+03   |
# |    ep_rew_mean          | 921        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 970        |
# |    time_elapsed         | 9948       |
# |    total_timesteps      | 1986560    |
# | train/                  |            |
# |    approx_kl            | 0.20803496 |
# |    clip_fraction        | 0.00991    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.104     |
# |    explained_variance   | 0.373      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 661        |
# |    n_updates            | 9690       |
# |    policy_gradient_loss | 0.00583    |
# |    value_loss           | 1.54e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.26e+03   |
# |    ep_rew_mean          | 931        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 971        |
# |    time_elapsed         | 9959       |
# |    total_timesteps      | 1988608    |
# | train/                  |            |
# |    approx_kl            | 0.09848431 |
# |    clip_fraction        | 0.00679    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.00204   |
# |    explained_variance   | 0.513      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 173        |
# |    n_updates            | 9700       |
# |    policy_gradient_loss | 0.00614    |
# |    value_loss           | 745        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.26e+03  |
# |    ep_rew_mean          | 931       |
# | time/                   |           |
# |    fps                  | 199       |
# |    iterations           | 972       |
# |    time_elapsed         | 9970      |
# |    total_timesteps      | 1990656   |
# | train/                  |           |
# |    approx_kl            | 0.3945535 |
# |    clip_fraction        | 0.0887    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.142    |
# |    explained_variance   | 0.15      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.99      |
# |    n_updates            | 9710      |
# |    policy_gradient_loss | -0.00905  |
# |    value_loss           | 18.4      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.26e+03   |
# |    ep_rew_mean          | 931        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 973        |
# |    time_elapsed         | 9981       |
# |    total_timesteps      | 1992704    |
# | train/                  |            |
# |    approx_kl            | 0.22061661 |
# |    clip_fraction        | 0.0474     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0224    |
# |    explained_variance   | -0.849     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.38       |
# |    n_updates            | 9720       |
# |    policy_gradient_loss | 0.00536    |
# |    value_loss           | 12.1       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.28e+03  |
# |    ep_rew_mean          | 931       |
# | time/                   |           |
# |    fps                  | 199       |
# |    iterations           | 974       |
# |    time_elapsed         | 9991      |
# |    total_timesteps      | 1994752   |
# | train/                  |           |
# |    approx_kl            | 0.5504094 |
# |    clip_fraction        | 0.0118    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00529  |
# |    explained_variance   | 0.823     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 34.7      |
# |    n_updates            | 9730      |
# |    policy_gradient_loss | 0.00361   |
# |    value_loss           | 672       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28e+03    |
# |    ep_rew_mean          | 931         |
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 975         |
# |    time_elapsed         | 10001       |
# |    total_timesteps      | 1996800     |
# | train/                  |             |
# |    approx_kl            | 0.032919995 |
# |    clip_fraction        | 0.00356     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.111      |
# |    explained_variance   | -1.02       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.881       |
# |    n_updates            | 9740        |
# |    policy_gradient_loss | 0.00138     |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28e+03    |
# |    ep_rew_mean          | 931         |
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 976         |
# |    time_elapsed         | 10012       |
# |    total_timesteps      | 1998848     |
# | train/                  |             |
# |    approx_kl            | 0.105841294 |
# |    clip_fraction        | 0.00811     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00578    |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 497         |
# |    n_updates            | 9750        |
# |    policy_gradient_loss | 0.00831     |
# |    value_loss           | 1.35e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.28e+03   |
# |    ep_rew_mean          | 941        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 977        |
# |    time_elapsed         | 10023      |
# |    total_timesteps      | 2000896    |
# | train/                  |            |
# |    approx_kl            | 0.27914435 |
# |    clip_fraction        | 0.0294     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0175    |
# |    explained_variance   | 0.496      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 725        |
# |    n_updates            | 9760       |
# |    policy_gradient_loss | 0.00187    |
# |    value_loss           | 938        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.28e+03   |
# |    ep_rew_mean          | 941        |
# | time/                   |            |
# |    fps                  | 199        |
# |    iterations           | 978        |
# |    time_elapsed         | 10035      |
# |    total_timesteps      | 2002944    |
# | train/                  |            |
# |    approx_kl            | 0.28054345 |
# |    clip_fraction        | 0.0198     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.103     |
# |    explained_variance   | 0.435      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 701        |
# |    n_updates            | 9770       |
# |    policy_gradient_loss | 0.00396    |
# |    value_loss           | 1.91e+03   |
# ----------------------------------------

# %% [markdown]
# # Evaluate the Model

# %%
model = PPO.load('./opt/trial_5_best_model.zip')

# %%
mean_reward, _ = evaluate_policy(model, env, render=True, n_eval_episodes=1)

# %%
mean_reward

# %% [markdown]
# # Test out the Model

# %%
obs = env.reset()

# %%
obs.shape

# %%
env.step(model.predict(obs)[0])

# %%
# Reset game to starting state
obs = env.reset()
# Set flag to flase
done = False
for game in range(1): 
    while not done: 
        if done: 
            obs = env.reset()
        env.render()
        action = model.predict(obs)[0]
        obs, reward, done, info = env.step(action)
        time.sleep(0.01)
        print(reward)
